# %% [markdown]
# ### Binary customer reviews classifier
# This project classifies a review into: a review that talks about the documentation vs a review that doesn't

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('data.csv')
df.describe()
# Out:
#                       Comment  Label
# count                     792    792
# unique                    648      2
# top     subscribe to my blog!  False
# freq                      110    587

# %%
# Preprocess the strings:
# 1. Remove special characters and singles stranded characters like s and m after ' removal
# 2. Remove single characters, replace multiple spaces with single space and convert to lower case
df['Comment'] = df['Comment'].str.replace(r'\W', ' ').str.replace(r'\s+[a-zA-Z0-9]\s+', ' ')
df['Comment'] = df['Comment'].str.replace(r'^[a-zA-Z0-9]\s+', '').str.replace(r'\s+', ' ').str.lower()

# %%
# 3. Drop duplicate comments
df.drop_duplicates(subset ="Comment", inplace = True)
df
# Out:
#                                                Comment  Label
# 0    please provide more direct way to get to the k...   True
# 1             confused about licences want mix of them  False
# 2                                  more logic tutorial   True
# 3                                          add feature  False
# 4    integrate with beacon technology and embedded ...  False
# 5                                          pretty good  False
# 6                                subscribe to my blog    True
# 7                                             all good  False
# 8                                    is very intuitive  False
# 19    great team of responsive peeps love the product   False
# 20            quicker support responses chat function   False
# 21   provide help tips at every field option with e...  False
# 22                                      excellent job   False
# 23   remove the requirement of offline access to th...  False
# 24   it doesn show the number if it is result of fo...  False
# 25                                 graphical interface  False
# 26                                            good app  False
# 29                      it easy to use and so pratice   False
# 30   its not so easy to design an app and the tutor...   True
# 31                                               pleno  False
# 32                                  nothing this great  False
# 33   more graphic options such as buttons and desig...  False
# 34                         voice recognition printings  False
# 35   simpler language for non technical people more...  False
# 36                                            best faq   True
# 37                                      bit confusing   False
# 38   love the input form feature but would like mor...  False
# 39                               es simplemente genial  False
# 40   wish there was help around how to configure fi...   True
# 41   easy to set up and run already introduced abou...  False
# ..                                                 ...    ...
# 758  more help videos grate app wish knew about it ...  False
# 759                         great program helps me lot  False
# 760  offering expanded tutorials guidance on how to...  False
# 761           set up instructions could be bit clearer   True
# 764  this is great if we could have calendar that w...   True
# 765                                           amazing   False
# 766                  keep on developing excellent job   False
# 768  love this application would like to be able to...  False
# 769  easy to use easy to make changes everybody is ...  False
# 770                          the best simply the best   False
# 771                                     very great app  False
# 772                 easier editing updating of content  False
# 773                      nothing yet still learning it  False
# 775  already have m just learning how it all works ...  False
# 776  extremely wonderful can think of anything that...  False
# 777                        interface not user friendly  False
# 778               little bit complicated but im trying  False
# 779  terminology related to errors in the app can b...  False
# 780                           it is doing my job easer  False
# 781                                        its amazing  False
# 782              include sample videos for basic needs  False
# 783  you guys are great can think of any improvemen...  False
# 784  most of my friends won need such tool as they ...  False
# 785                                           awesome   False
# 786  nothing well maybe one thing ship paseo sandwi...  False
# 787  just started working with it so far love it am...  False
# 788               make it video tutorial per mini task  False
# 789  always tell all of my friend that using this a...  False
# 790  just new to this but fantastic so far will be ...  False
# 791                                   more ui options   False
#
# [625 rows x 2 columns]

# %%
# Lemmatize the words
import nltk

def lemmatize(sentence):
    tokenizer = nltk.tokenize.WhitespaceTokenizer()
    lemmatizer = nltk.stem.WordNetLemmatizer()
    lemmatized = []
    for word in tokenizer.tokenize(sentence):
        lemmatized.append(lemmatizer.lemmatize(word))
    return " ".join(lemmatized)
df['Comment'] = df['Comment'].apply(lemmatize)
df
# Out:
#                                                Comment  Label
# 0    please provide more direct way to get to the k...   True
# 1              confused about licence want mix of them  False
# 2                                  more logic tutorial   True
# 3                                          add feature  False
# 4    integrate with beacon technology and embedded ...  False
# 5                                          pretty good  False
# 6                                 subscribe to my blog   True
# 7                                             all good  False
# 8                                    is very intuitive  False
# 19      great team of responsive peep love the product  False
# 20              quicker support response chat function  False
# 21   provide help tip at every field option with ex...  False
# 22                                       excellent job  False
# 23   remove the requirement of offline access to th...  False
# 24   it doesn show the number if it is result of fo...  False
# 25                                 graphical interface  False
# 26                                            good app  False
# 29                       it easy to use and so pratice  False
# 30   it not so easy to design an app and the tutori...   True
# 31                                               pleno  False
# 32                                  nothing this great  False
# 33   more graphic option such a button and design a...  False
# 34                          voice recognition printing  False
# 35   simpler language for non technical people more...  False
# 36                                            best faq   True
# 37                                       bit confusing  False
# 38   love the input form feature but would like mor...  False
# 39                                e simplemente genial  False
# 40   wish there wa help around how to configure fie...   True
# 41   easy to set up and run already introduced abou...  False
# ..                                                 ...    ...
# 758  more help video grate app wish knew about it y...  False
# 759                          great program help me lot  False
# 760  offering expanded tutorial guidance on how to ...  False
# 761            set up instruction could be bit clearer   True
# 764  this is great if we could have calendar that w...   True
# 765                                            amazing  False
# 766                   keep on developing excellent job  False
# 768  love this application would like to be able to...  False
# 769  easy to use easy to make change everybody is h...  False
# 770                           the best simply the best  False
# 771                                     very great app  False
# 772                 easier editing updating of content  False
# 773                      nothing yet still learning it  False
# 775  already have m just learning how it all work b...  False
# 776  extremely wonderful can think of anything that...  False
# 777                        interface not user friendly  False
# 778               little bit complicated but im trying  False
# 779  terminology related to error in the app can be...  False
# 780                           it is doing my job easer  False
# 781                                         it amazing  False
# 782                include sample video for basic need  False
# 783  you guy are great can think of any improvement...  False
# 784  most of my friend won need such tool a they do...  False
# 785                                            awesome  False
# 786  nothing well maybe one thing ship paseo sandwi...  False
# 787  just started working with it so far love it am...  False
# 788               make it video tutorial per mini task  False
# 789  always tell all of my friend that using this a...  False
# 790  just new to this but fantastic so far will be ...  False
# 791                                     more ui option  False
#
# [625 rows x 2 columns]

# %%
df['Comment']
# Out:
# 0      please provide more direct way to get to the k...
# 1                confused about licence want mix of them
# 2                                    more logic tutorial
# 3                                            add feature
# 4      integrate with beacon technology and embedded ...
# 5                                            pretty good
# 6                                   subscribe to my blog
# 7                                               all good
# 8                                      is very intuitive
# 19        great team of responsive peep love the product
# 20                quicker support response chat function
# 21     provide help tip at every field option with ex...
# 22                                         excellent job
# 23     remove the requirement of offline access to th...
# 24     it doesn show the number if it is result of fo...
# 25                                   graphical interface
# 26                                              good app
# 29                         it easy to use and so pratice
# 30     it not so easy to design an app and the tutori...
# 31                                                 pleno
# 32                                    nothing this great
# 33     more graphic option such a button and design a...
# 34                            voice recognition printing
# 35     simpler language for non technical people more...
# 36                                              best faq
# 37                                         bit confusing
# 38     love the input form feature but would like mor...
# 39                                  e simplemente genial
# 40     wish there wa help around how to configure fie...
# 41     easy to set up and run already introduced abou...
#                              ...
# 758    more help video grate app wish knew about it y...
# 759                            great program help me lot
# 760    offering expanded tutorial guidance on how to ...
# 761              set up instruction could be bit clearer
# 764    this is great if we could have calendar that w...
# 765                                              amazing
# 766                     keep on developing excellent job
# 768    love this application would like to be able to...
# 769    easy to use easy to make change everybody is h...
# 770                             the best simply the best
# 771                                       very great app
# 772                   easier editing updating of content
# 773                        nothing yet still learning it
# 775    already have m just learning how it all work b...
# 776    extremely wonderful can think of anything that...
# 777                          interface not user friendly
# 778                 little bit complicated but im trying
# 779    terminology related to error in the app can be...
# 780                             it is doing my job easer
# 781                                           it amazing
# 782                  include sample video for basic need
# 783    you guy are great can think of any improvement...
# 784    most of my friend won need such tool a they do...
# 785                                              awesome
# 786    nothing well maybe one thing ship paseo sandwi...
# 787    just started working with it so far love it am...
# 788                 make it video tutorial per mini task
# 789    always tell all of my friend that using this a...
# 790    just new to this but fantastic so far will be ...
# 791                                       more ui option
# Name: Comment, Length: 625, dtype: object

# %%
# Convert to TFIDF feature values
from sklearn.feature_extraction.text import TfidfVectorizer  
tfidfconverter = TfidfVectorizer(stop_words=stopwords.words('english'))  
vectorized = tfidfconverter.fit_transform(df['Comment']).toarray()

# %%
# Split into train and test sets
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(vectorized, df['Label'], test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=10, random_state=0)  
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
# Predict the test set
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, accuracy_score

# Evaluate the model
print(classification_report(y_test,y_pred))  
print(accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.91      1.00      0.95       110
#         True       1.00      0.27      0.42        15
#
#    micro avg       0.91      0.91      0.91       125
#    macro avg       0.95      0.63      0.69       125
# weighted avg       0.92      0.91      0.89       125
#
# 0.912

# %%
# create a baseline
from sklearn.dummy import DummyClassifier
dummy_classifier = DummyClassifier(strategy="stratified")
dummy_classifier.fit(X_train, y_train)
baseline_pred = dummy_classifier.predict(X_test)

# %%
# Evaluate the dummy classifier
print(classification_report(y_test,baseline_pred))  
print(accuracy_score(y_test, baseline_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.89      0.85      0.87       110
#         True       0.16      0.20      0.18        15
#
#    micro avg       0.78      0.78      0.78       125
#    macro avg       0.52      0.53      0.52       125
# weighted avg       0.80      0.78      0.79       125
#
# 0.776

# %%
# Model performs better than baseline, woot!
